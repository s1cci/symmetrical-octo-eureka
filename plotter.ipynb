# %% [markdown]
# <a href="https://colab.research.google.com/github/s1cci/symmetrical-octo-eureka/blob/main/plotter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Funktionsplotter
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-10, 10, 0.1)
y = x**4+3*x**2+7
plt.plot(x, y)
plt.show
# Out:
# <function matplotlib.pyplot.show>
